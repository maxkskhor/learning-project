# %%
class ListNode:
    def __init__(self, val):
        self.val = val
        self.next = None
    
one = ListNode(1)
two = ListNode(2)
three = ListNode(3)
one.next = two
two.next = three
head = one

print(head.val)
print(head.next.val)
print(head.next.next.val)
# Out:
# 1
# 2
# 3

# %%
ptr = head
head = head.next
head = None

# %%
def get_sum(head):
    ans = 0
    while head:
        ans += head.val
        head = head.next
    
    return ans

# %%
        while curr and curr.next:
            nextnext_node = curr.next.next
            next_node = curr.next
            next_node.next = curr
            
            curr.next = prev
            dummy = curr
            curr = nextnext_node
            prev = next_node
